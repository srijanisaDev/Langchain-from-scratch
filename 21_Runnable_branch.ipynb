# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
from langchain_core.runnables import RunnableSequence, RunnableParallel, RunnablePassthrough, RunnableBranch, RunnableLambda

load_dotenv()

prompt1 = PromptTemplate(
    template='Write a detailed report on {topic}',
    input_variables=['topic']
)

prompt2 = PromptTemplate(
    template='Summarize the following text \n {text}',
    input_variables=['text']
)

model = ChatGoogleGenerativeAI (
    model="gemini-2.5-flash",
    temperature=0,
)

parser = StrOutputParser()

report_gen_chain = prompt1 | model | parser

branch_chain = RunnableBranch(
    (lambda x: len(x.split())>300, prompt2 | model | parser),
    RunnablePassthrough()
)

final_chain = RunnableSequence(report_gen_chain, branch_chain)

print(final_chain.invoke({'topic':'Russia vs Ukraine'}))
# Out:
# The Russia-Ukraine conflict is a complex struggle rooted in centuries of shared history, divergent geopolitical aspirations, and a fundamental clash over Ukraine's sovereignty. While tensions simmered since Ukraine's 1991 independence, the conflict dramatically escalated in 2014 with Russia's annexation of Crimea and support for separatists in eastern Ukraine's Donbas region, leading to a low-intensity war.
#
# On February 24, 2022, Russia launched a full-scale invasion, initiating Europe's largest conventional war since WWII. Initial Russian attempts to seize Kyiv failed, leading to a refocus on securing Donbas and southern Ukraine. Ukrainian forces, bolstered by Western aid, launched successful counter-offensives in late 2022. As of late 2023, the conflict is a grinding war of attrition along a 1,000-kilometer front line.
#
# The conflict has had profound impacts:
# *   **Military:** Ukrainian forces, highly motivated and equipped with Western weaponry, have effectively resisted Russian forces, which have adapted to a war of attrition. Both sides have suffered tens of thousands of casualties.
# *   **Political:** Ukraine seeks full territorial integrity and Euro-Atlantic integration, while Russia has illegally annexed four Ukrainian regions. Globally, the conflict has reshaped geopolitics, strengthening Western alliances and prompting NATO expansion.
# *   **Economic:** Ukraine's economy is devastated and reliant on international aid, while Russia faces unprecedented international sanctions. Global energy and food markets have been significantly disrupted.
# *   **Humanitarian:** Millions of Ukrainians are displaced, thousands of civilians have been killed, and widespread infrastructure destruction and human rights abuses have been reported.
#
# The international community has largely condemned Russia's actions, imposing extensive sanctions, providing billions in military, financial, and humanitarian aid to Ukraine, and prompting Finland and Sweden to join NATO.
#
# As of late 2023, the conflict is largely a stalemate with no immediate end in sight, and prospects for a negotiated settlement are dim. The most likely future scenario is a protracted war of attrition, though Ukrainian breakthroughs or a frozen conflict remain possibilities. The conflict is a defining geopolitical event, challenging international law and security architecture, with immense human cost and far-reaching global implications.
