# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableSequence

# %%
load_dotenv()
# Out:
# True

# %%
prompt1 = PromptTemplate(
    template = 'Write one joke about {topic}',
    input_variables=['topic']
)

# %%
model = ChatGoogleGenerativeAI (
    model="gemini-2.5-flash",
    temperature=0,
)

# %%
parser = StrOutputParser()

# %%
prompt2 = PromptTemplate(
    template = 'explain the Following Joke - {text}',
    input_variables=['topic']
)

# %%
chain = RunnableSequence(prompt1,model,parser , prompt2 , model , parser)

# %%
print(chain.invoke({'topic' : 'AI'}))
# Out:
# This joke plays on a clever pun using the phrase "processing power" in two different contexts:
#
# 1.  **Literal (Technical) Meaning:**
#     *   An **AI (Artificial Intelligence)** is a highly complex system that requires immense computational resources to function, learn, and make decisions. It needs a vast amount of "processing power" in the technical sense – fast processors, lots of memory, etc.
#     *   A **calculator**, on the other hand, is a very simple device designed for basic arithmetic. It has extremely limited "processing power" compared to an AI.
#
# 2.  **Figurative (Relationship) Meaning:**
#     *   In a relationship context, "processing power" can be interpreted metaphorically. It refers to a partner's ability to understand, analyze, deal with complex emotions, thoughts, and situations. It implies intellectual depth, emotional intelligence, and the capacity to engage in meaningful, complex interactions.
#
# **The Joke Explained:**
#
# The humor comes from the AI applying its own technical jargon to a very human relationship problem:
#
# *   **"They just didn't have enough in common":** This is a classic breakup line. From an AI's perspective, a calculator truly has very little in common with its advanced capabilities and complex "thoughts."
# *   **"It needed more *processing* power in a relationship":** This is the punchline. The AI is saying:
#     *   **Literally:** The calculator is computationally too simple and limited to be a compatible partner for an AI.
#     *   **Figuratively:** The calculator lacks the intellectual and emotional depth (the "processing power" for complex thoughts and feelings) that an advanced AI would seek in a companion.
#
# The joke is funny because it anthropomorphizes the AI, giving it human relationship problems, but then uses its technical nature to deliver the reason for the breakup in a clever, pun-filled way.
