# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI (
    model="gemini-2.5-flash",
    temperature=0,
)

# %%
prompt1 = PromptTemplate(
    template='Generate a detailed report on {topic}',
    input_variables=['topic']
)

# %%
prompt2 = PromptTemplate(
    template='Generate a 5 pointer summary from the following text \n {text}',
    input_variables=['text']
)

# %%
parser = StrOutputParser()

# %%
chain = prompt1 | model | parser | prompt2 | model | parser

# %%
result = chain.invoke({'topic' : 'unemployment in India'})

# %%
print(result)
# Out:
# Here's a 5-pointer summary of the detailed report on unemployment in India:
#
# 1.  **Persistent Challenge with "Jobless Growth":** India faces a complex and persistent unemployment challenge, characterized by "jobless growth" where robust economic expansion hasn't created enough formal employment. Key issues include high youth unemployment (especially among educated youth), low female labour force participation, and widespread underemployment and disguised unemployment.
# 2.  **Key Drivers:** The primary causes stem from a massive demographic youth bulge, a significant skill mismatch between the education system and industry demands, the dominance of the informal sector (over 80% of the workforce), and slow growth in the manufacturing sector despite initiatives like "Make in India."
# 3.  **Far-Reaching Impacts:** High unemployment leads to severe economic consequences such as reduced GDP, increased poverty, and potential brain drain. Socially, it fuels unrest, contributes to mental health issues, erodes human capital, and can lead to political instability.
# 4.  **Government Initiatives:** The Indian government has launched various programs to tackle unemployment, including the Skill India Mission and PMKVY for skill development, Make in India and Startup India for job creation and entrepreneurship, MGNREGA as a rural safety net, and Production Linked Incentive (PLI) schemes to boost manufacturing.
# 5.  **Multi-pronged Way Forward:** Addressing the issue requires a sustained, multi-pronged approach focusing on revitalizing manufacturing and MSMEs, enhancing skill development and education reform aligned with industry needs, promoting entrepreneurship, formalizing the informal sector, and significantly boosting female labour force participation.

# %%
chain.get_graph().print_ascii()
# Out:
#       +-------------+
#       | PromptInput |
#       +-------------+
#              *
#              *
#              *
#     +----------------+
#     | PromptTemplate |
#     +----------------+
#              *
#              *
#              *
# +------------------------+
# | ChatGoogleGenerativeAI |
# +------------------------+
#              *
#              *
#              *
#     +-----------------+
#     | StrOutputParser |
#     +-----------------+
#              *
#              *
#              *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+
#              *
#              *
#              *
#     +----------------+
#     | PromptTemplate |
#     +----------------+
#              *
#              *
#              *
# +------------------------+
# | ChatGoogleGenerativeAI |
# +------------------------+
#              *
#              *
#              *
#     +-----------------+
#     | StrOutputParser |
#     +-----------------+
#              *
#              *
#              *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+
