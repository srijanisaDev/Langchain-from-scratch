# %%
import random

# %%
class NakliLLM() :
    
    def __init__(self):
        print('LLM created')

    def predict(self,prompt):

        response_List = [
            "Ye sab kya krna pad raha hai",
            "Acha hua mai andha hu",
            "Ye haath mujhe de de thakur"
        ]    

        return {'response': random.choice(response_List)}

# %%
llm  = NakliLLM()
# Out:
# LLM created

# %%
llm.predict('what is the capital of India')
# Out:
# {'response': 'Ye sab kya krna pad raha hai'}

# %%
class NakliPromptTemplate:

    def __init__(self,template,input_variables):
        self.template = template
        self.input_variables = input_variables

    def format(self,input_dict):
        return self.template.format(**input_dict)

# %%
template = NakliPromptTemplate(
    template = 'Write {length} Notes on {topic}',
    input_variables = ['topic']
)

# %%
prompt = template.format({'length' : 'long' , 'topic' : 'quantum entanglement'})

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
llm.predict(prompt)
# Out:
# {'response': 'Ye haath mujhe de de thakur'}

# %%
class NakliLLMChain:

    def __init__(self,llm,prompt):
        self.llm = llm
        self.prompt = prompt

    def run(self,input_dict):
        final_prompt = self.prompt.format(input_dict)
        result = self.llm.predict(final_prompt)    

        return result['response']

# %%
template = NakliPromptTemplate(
    template = 'Write {length} Notes on {topic}',
    input_variables = ['topic']
)

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
chain = NakliLLMChain(llm,template)

# %%
chain.run({'length' : 'short' , 'topic' : 'india'})
# Out:
# 'Acha hua mai andha hu'

# %%
from abc import ABC , abstractmethod

# %%
class Runnable(ABC):
    @abstractmethod
    def invoke(input_data):
        pass

# %%
class NakliLLM(Runnable) :
    
    def __init__(self):
        print('LLM created')

    def invoke(self,prompt):
        response_List = [
            "Ye sab kya krna pad raha hai",
            "Acha hua mai andha hu",
            "Ye haath mujhe de de thakur"
        ]    

        return {'response': random.choice(response_List)}        

    def predict(self,prompt):

        response_List = [
            "Ye sab kya krna pad raha hai",
            "Acha hua mai andha hu",
            "Ye haath mujhe de de thakur"
        ]    

        return {'response': random.choice(response_List)}

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
class NakliPromptTemplate(Runnable):

    def __init__(self,template,input_variables):
        self.template = template
        self.input_variables = input_variables

    def invoke(self,input_dict):
        return self.template.format(**input_dict) 


    def format(self,input_dict):
        return self.template.format(**input_dict)

# %%
class RunnableConnector(Runnable):

    def __init__(self,runnable_list):
        self.runnable_list = runnable_list

    def invoke(self,input_data):

        for runnable in self.runnable_list:
            input_data = runnable.invoke(input_data) 

        return input_data

# %%
template = NakliPromptTemplate(
    template = 'Write {length} Notes on {topic}',
    input_variables = ['topic']
)

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
chain = RunnableConnector([template,llm])

# %%
chain.invoke({'length' : 'long' , 'topic' : 'black hole'})
# Out:
# {'response': 'Ye sab kya krna pad raha hai'}
